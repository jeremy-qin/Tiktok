# %%
# !pip install pandas
# Out:
# Collecting pandas
#   Downloading pandas-1.3.5-cp39-cp39-win_amd64.whl (10.2 MB)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\jerem\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from pandas) (2.8.2)
# Collecting pytz>=2017.3
#   Downloading pytz-2021.3-py2.py3-none-any.whl (503 kB)
# Collecting numpy>=1.17.3
#   Downloading numpy-1.21.4-cp39-cp39-win_amd64.whl (14.0 MB)
# Requirement already satisfied: six>=1.5 in c:\users\jerem\appdata\local\packages\pythonsoftwarefoundation.python.3.9_qbz5n2kfra8p0\localcache\local-packages\python39\site-packages (from python-dateutil>=2.7.3->pandas) (1.16.0)
# Installing collected packages: pytz, numpy, pandas
# Successfully installed numpy-1.21.4 pandas-1.3.5 pytz-2021.3
#   WARNING: The script f2py.exe is installed in 'C:\Users\jerem\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# WARNING: You are using pip version 21.2.4; however, version 21.3.1 is available.
# You should consider upgrading via the 'C:\Users\jerem\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip' command.

# %%
import pandas as pd

# %%
df = pd.read_json('export.json')

# %%
df.head()
# Out:
#                     id                                               desc  \
# 0  6914157190987271168  Oh Julius 😅 "Julius the Python" on YouTube #ju...
# 1  6909838234151422976  stain.. Petit python banana..😍#fyp  #ballpytho...
# 2  6958430060340694016  Happy birthday little buddy 🐍 #snake #python #...
# 3  6980527845726604288  lil too busy worried about snacks.. #Python #d...
# 4  6840796191161175040  Check out this baby python! Did you kno their ...
#
#    createTime                                              video  \
# 0  1609827712  {'id': '6914157190987271430', 'height': 480, '...
# 1  1608822085  {'id': '6909838234151423234', 'height': 960, '...
# 2  1620135755  {'id': '6958430060340694278', 'height': 1024, ...
# 3  1625280797  {'id': '6980527845726604549', 'height': 1024, ...
# 4  1592746983  {'id': '6840796191161175302', 'height': 1024, ...
#
#                                               author  \
# 0  {'id': '6815401436291580934', 'uniqueId': '666...
# 1  {'id': '6879407363858793478', 'uniqueId': 'ale...
# 2  {'id': '6700343527676740613', 'uniqueId': 'the...
# 3  {'id': '6797473463524148230', 'uniqueId': 'cac...
# 4  {'id': '6699542567460389894', 'uniqueId': 'jay...
#
#                                                music  \
# 0  {'id': '6914157155620801286', 'title': 'origin...
# 1  {'id': '6623108046656637701', 'title': 'Follow...
# 2  {'id': '6800370585814697986', 'title': 'Intent...
# 3  {'id': '6980527635675745029', 'title': 'origin...
# 4  {'id': '6754296561716447233', 'title': 'Roses ...
#
#                                           challenges  \
# 0  [{'id': '1688028247347206', 'title': 'juliusth...
# 1  [{'id': '229207', 'title': 'fyp', 'desc': '', ...
# 2  [{'id': '37769', 'title': 'snake', 'desc': 'Il...
# 3  [{'id': '163195', 'title': 'python', 'desc': '...
# 4  [{'id': '1597138111108097', 'title': 'animalso...
#
#                                                stats             duetInfo  \
# 0  {'diggCount': 3500000, 'shareCount': 271100, '...  {'duetFromId': '0'}
# 1  {'diggCount': 2600000, 'shareCount': 36900, 'c...  {'duetFromId': '0'}
# 2  {'diggCount': 2200000, 'shareCount': 16400, 'c...  {'duetFromId': '0'}
# 3  {'diggCount': 1900000, 'shareCount': 38200, 'c...  {'duetFromId': '0'}
# 4  {'diggCount': 1900000, 'shareCount': 15500, 'c...  {'duetFromId': '0'}
#
#    originalItem  ...  privateItem duetEnabled  stitchEnabled  shareEnabled  \
# 0         False  ...        False        True           True          True
# 1         False  ...        False       False          False          True
# 2         False  ...        False       False          False          True
# 3         False  ...        False        True           True          True
# 4         False  ...        False        True           True          True
#
#                                       stickersOnItem   isAd  duetDisplay  \
# 0  [{'stickerType': 4, 'stickerText': ['That time...  False            0
# 1                                                NaN  False            0
# 2                                                NaN  False            0
# 3  [{'stickerType': 9, 'stickerText': ['Dog steps...  False            0
# 4                                                NaN  False            0
#
#    stitchDisplay  warnInfo effectStickers
# 0              0       NaN            NaN
# 1              0       NaN            NaN
# 2              0       NaN            NaN
# 3              0       NaN            NaN
# 4              0       NaN            NaN
#
# [5 rows x 30 columns]

# %%
import json

# %%
with open('export.json', 'r') as f:
    data = json.load(f)

# %%
nested_values = ['video', 'author', 'music', 'stats', 'authorStats', 'challenges', ' duetInfo', 'testExtra', 'stickersOnItem']
skip_values = ['challenges', ' duetInfo', 'testExtra', 'stickersOnItem']

# %%
# Create blank dictionary
flattened_data = {}
#Loop through each video
for idx, value in enumerate(data):
    flattened_data[idx] = {}
    #Loop through each property in each video
    for prop_idx, prop_value in value.items():
        #Check if nested
        if prop_idx in nested_values:
            if prop_idx in skip_values:
                pass
            else:
                #Loop through each nested property
                for nested_idx, nested_value in prop_value.items():
                    flattened_data[idx][prop_idx+'_'+nested_idx] = nested_value
        #If not nested, add back to  flattened dictionary
        else:
            flattened_data[idx][prop_idx] = prop_value

# %%
flattened_data[0]
# Out:
# {'id': '6914157190987271430',
#  'desc': 'Oh Julius 😅 "Julius the Python" on YouTube #juliusthesnake #python #snakes #petsnakes #reptiles #bigsnakes #exoticpet #burmesepython #funnyanimals',
#  'createTime': 1609827712,
#  'video_id': '6914157190987271430',
#  'video_height': 480,
#  'video_width': 640,
#  'video_duration': 9,
#  'video_ratio': '480p',
#  'video_cover': 'https://p16-sign-va.tiktokcdn.com/obj/tos-maliva-p-0068/f8b44ab15bd64f4ba820bc477f485a10_1609827713?x-expires=1639476000&x-signature=y02ipxaDY0mh8gH%2BAxuaY9SOm7A%3D',
#  'video_originCover': 'https://p16-sign-va.tiktokcdn.com/obj/tos-maliva-p-0068/41cd16b79320490bbd12e6f5f3d9b06a_1609827713?x-expires=1639476000&x-signature=dKh3qLnjCoE0f9ZTkjpQsYru7Ak%3D',
#  'video_dynamicCover': 'https://p16-sign-va.tiktokcdn.com/obj/tos-maliva-p-0068/ec2039a008c24b859c00aa3aa3971c9c_1609827714?x-expires=1639476000&x-signature=cnfiuDXBif6FyCSZw0YIjnR7do8%3D',
#  'video_playAddr': 'https://v16-web.tiktok.com/video/tos/useast2a/tos-useast2a-ve-0068c001/027aa7b9454044f98520401bbb5eaf44/?a=1988&br=816&bt=408&cd=0%7C0%7C1&ch=0&cr=0&cs=0&cv=1&dr=0&ds=2&er=&expire=1639478139&ft=wUyFfFFnkag3-I&l=20211214043530010245136103010AFCE8&lr=tiktok_m&mime_type=video_mp4&net=0&pl=0&policy=3&qs=0&rc=ajV1eXNtNXkzeTMzNTczM0ApNDo8OmY0Mzs3N2lkOzhnZGduNHM2NDAwXm5fLS1fMTZzczIzYy9iYDAyMTJgNjYwYWM6Yw%3D%3D&signature=0016104f565d549828fd3371c676e000&tk=0&vl=&vr=',
#  'video_downloadAddr': 'https://v16-web.tiktok.com/video/tos/useast2a/tos-useast2a-ve-0068c001/027aa7b9454044f98520401bbb5eaf44/?a=1988&br=816&bt=408&cd=0%7C0%7C1&ch=0&cr=0&cs=0&cv=1&dr=0&ds=2&er=&expire=1639478139&ft=wUyFfFFnkag3-I&l=20211214043530010245136103010AFCE8&lr=tiktok_m&mime_type=video_mp4&net=0&pl=0&policy=3&qs=0&rc=ajV1eXNtNXkzeTMzNTczM0ApNDo8OmY0Mzs3N2lkOzhnZGduNHM2NDAwXm5fLS1fMTZzczIzYy9iYDAyMTJgNjYwYWM6Yw%3D%3D&signature=0016104f565d549828fd3371c676e000&tk=0&vl=&vr=',
#  'video_shareCover': ['',
#   'https://p16-sign-va.tiktokcdn.com/tos-maliva-p-0068/41cd16b79320490bbd12e6f5f3d9b06a_1609827713~tplv-tiktok-play.jpeg?x-expires=1639476000&x-signature=4qr%2BJFrm7x6faF9u8vwusjAdzsU%3D',
#   'https://p16-sign-va.tiktokcdn.com/tos-maliva-p-0068/41cd16b79320490bbd12e6f5f3d9b06a_1609827713~tplv-tiktokx-share-play.jpeg?x-expires=1639476000&x-signature=dGTQJ0BUlwRrpqmX89i2L9rgars%3D'],
#  'video_reflowCover': 'https://p16-sign-va.tiktokcdn.com/obj/tos-maliva-p-0068/f8b44ab15bd64f4ba820bc477f485a10_1609827713?x-expires=1639476000&x-signature=y02ipxaDY0mh8gH%2BAxuaY9SOm7A%3D',
#  'video_bitrate': 418808,
#  'video_encodedType': 'normal',
#  'video_format': 'mp4',
#  'video_videoQuality': 'normal',
#  'video_encodeUserTag': '',
#  'video_codecType': 'h264',
#  'video_definition': '480p',
#  'author_id': '6815401436291580934',
#  'author_uniqueId': '666zomey',
#  'author_nickname': 'Zomey',
#  'author_avatarThumb': 'https://p16-sign-va.tiktokcdn.com/musically-maliva-obj/1679299931530245~c5_100x100.jpeg?x-expires=1639540800&x-signature=cW3s%2FHQ3OIF0bKxSfof4rwWa2ls%3D',
#  'author_avatarMedium': 'https://p16-sign-va.tiktokcdn.com/musically-maliva-obj/1679299931530245~c5_720x720.jpeg?x-expires=1639540800&x-signature=GwsMPg78bo%2FN1ip0cqTo3zcSEMw%3D',
#  'author_avatarLarger': 'https://p16-sign-va.tiktokcdn.com/musically-maliva-obj/1679299931530245~c5_1080x1080.jpeg?x-expires=1639540800&x-signature=nuy8tTz0jhW2sZbqx6jAeEfnhyo%3D',
#  'author_signature': "~ PDX. 🏳️\u200d🌈. Wine. Animals. Humor ~\nInsta '666zomey'",
#  'author_verified': False,
#  'author_secUid': 'MS4wLjABAAAAmKLjce6rFzxV0HuEfYOm5dh-tCsyPyhTdnqj-ebq1Hozp7r91zmbf3-6UirgSZhm',
#  'author_secret': False,
#  'author_ftc': False,
#  'author_relation': 0,
#  'author_openFavorite': False,
#  'author_commentSetting': 0,
#  'author_duetSetting': 0,
#  'author_stitchSetting': 0,
#  'author_privateAccount': False,
#  'author_isADVirtual': False,
#  'music_id': '6914157155620801286',
#  'music_title': 'original sound',
#  'music_playUrl': 'https://sf16-ies-music-va.tiktokcdn.com/obj/musically-maliva-obj/6914157149086108421.mp3',
#  'music_coverThumb': 'https://p16-sign-va.tiktokcdn.com/musically-maliva-obj/1679299931530245~c5_100x100.jpeg?x-expires=1639540800&x-signature=cW3s%2FHQ3OIF0bKxSfof4rwWa2ls%3D',
#  'music_coverMedium': 'https://p16-sign-va.tiktokcdn.com/musically-maliva-obj/1679299931530245~c5_720x720.jpeg?x-expires=1639540800&x-signature=GwsMPg78bo%2FN1ip0cqTo3zcSEMw%3D',
#  'music_coverLarge': 'https://p16-sign-va.tiktokcdn.com/musically-maliva-obj/1679299931530245~c5_1080x1080.jpeg?x-expires=1639540800&x-signature=nuy8tTz0jhW2sZbqx6jAeEfnhyo%3D',
#  'music_authorName': 'Zomey',
#  'music_original': True,
#  'music_duration': 8,
#  'music_album': '',
#  'stats_diggCount': 3500000,
#  'stats_shareCount': 271100,
#  'stats_commentCount': 73100,
#  'stats_playCount': 26500000,
#  'duetInfo': {'duetFromId': '0'},
#  'originalItem': False,
#  'officalItem': False,
#  'textExtra': [{'awemeId': '',
#    'start': 44,
#    'end': 59,
#    'hashtagName': 'juliusthesnake',
#    'hashtagId': '1688028247347206',
#    'type': 1,
#    'userId': '',
#    'isCommerce': False,
#    'userUniqueId': '',
#    'secUid': '',
#    'subType': 0},
#   {'awemeId': '',
#    'start': 60,
#    'end': 67,
#    'hashtagName': 'python',
#    'hashtagId': '163195',
#    'type': 1,
#    'userId': '',
#    'isCommerce': False,
#    'userUniqueId': '',
#    'secUid': '',
#    'subType': 0},
#   {'awemeId': '',
#    'start': 68,
#    'end': 75,
#    'hashtagName': 'snakes',
#    'hashtagId': '55989',
#    'type': 1,
#    'userId': '',
#    'isCommerce': False,
#    'userUniqueId': '',
#    'secUid': '',
#    'subType': 0},
#   {'awemeId': '',
#    'start': 76,
#    'end': 86,
#    'hashtagName': 'petsnakes',
#    'hashtagId': '12175144',
#    'type': 1,
#    'userId': '',
#    'isCommerce': False,
#    'userUniqueId': '',
#    'secUid': '',
#    'subType': 0},
#   {'awemeId': '',
#    'start': 87,
#    'end': 96,
#    'hashtagName': 'reptiles',
#    'hashtagId': '204835',
#    'type': 1,
#    'userId': '',
#    'isCommerce': False,
#    'userUniqueId': '',
#    'secUid': '',
#    'subType': 0},
#   {'awemeId': '',
#    'start': 97,
#    'end': 107,
#    'hashtagName': 'bigsnakes',
#    'hashtagId': '14708816',
#    'type': 1,
#    'userId': '',
#    'isCommerce': False,
#    'userUniqueId': '',
#    'secUid': '',
#    'subType': 0},
#   {'awemeId': '',
#    'start': 108,
#    'end': 118,
#    'hashtagName': 'exoticpet',
#    'hashtagId': '12390175',
#    'type': 1,
#    'userId': '',
#    'isCommerce': False,
#    'userUniqueId': '',
#    'secUid': '',
#    'subType': 0},
#   {'awemeId': '',
#    'start': 119,
#    'end': 133,
#    'hashtagName': 'burmesepython',
#    'hashtagId': '17154764',
#    'type': 1,
#    'userId': '',
#    'isCommerce': False,
#    'userUniqueId': '',
#    'secUid': '',
#    'subType': 0},
#   {'awemeId': '',
#    'start': 134,
#    'end': 147,
#    'hashtagName': 'funnyanimals',
#    'hashtagId': '487800',
#    'type': 1,
#    'userId': '',
#    'isCommerce': False,
#    'userUniqueId': '',
#    'secUid': '',
#    'subType': 0}],
#  'secret': False,
#  'forFriend': False,
#  'digged': False,
#  'itemCommentStatus': 0,
#  'showNotPass': False,
#  'vl1': False,
#  'itemMute': False,
#  'authorStats_followingCount': 581,
#  'authorStats_followerCount': 103900,
#  'authorStats_heartCount': 4600000,
#  'authorStats_videoCount': 157,
#  'authorStats_diggCount': 2939,
#  'authorStats_heart': 4600000,
#  'privateItem': False,
#  'duetEnabled': True,
#  'stitchEnabled': True,
#  'shareEnabled': True,
#  'isAd': False,
#  'duetDisplay': 0,
#  'stitchDisplay': 0}

# %%
df_test = pd.DataFrame.from_dict(flattened_data, orient="index")

# %%
df_test.head()
# Out:
#                     id                                               desc  \
# 0  6914157190987271430  Oh Julius 😅 "Julius the Python" on YouTube #ju...
# 1  6909838234151423234  stain.. Petit python banana..😍#fyp  #ballpytho...
# 2  6958430060340694278  Happy birthday little buddy 🐍 #snake #python #...
# 3  6980527845726604549  lil too busy worried about snacks.. #Python #d...
# 4  6840796191161175302  Check out this baby python! Did you kno their ...
#
#    createTime             video_id  video_height  video_width  video_duration  \
# 0  1609827712  6914157190987271430           480          640               9
# 1  1608822085  6909838234151423234           960          540              15
# 2  1620135755  6958430060340694278          1024          576              20
# 3  1625280797  6980527845726604549          1024          576               7
# 4  1592746983  6840796191161175302          1024          576              18
#
#   video_ratio                                        video_cover  \
# 0        480p  https://p16-sign-va.tiktokcdn.com/obj/tos-mali...
# 1        720p  https://p16-sign-sg.tiktokcdn.com/obj/tos-alis...
# 2        720p  https://p16-sign-va.tiktokcdn.com/obj/tos-mali...
# 3        720p  https://p16-sign-va.tiktokcdn.com/tos-maliva-p...
# 4        720p  https://p16-sign-va.tiktokcdn.com/obj/tos-mali...
#
#                                    video_originCover  ... authorStats_heart  \
# 0  https://p16-sign-va.tiktokcdn.com/obj/tos-mali...  ...           4600000
# 1  https://p16-sign-sg.tiktokcdn.com/obj/tos-alis...  ...           5600000
# 2  https://p16-sign-va.tiktokcdn.com/obj/tos-mali...  ...         147000000
# 3  https://p16-sign-va.tiktokcdn.com/obj/tos-mali...  ...          14300000
# 4  https://p16-sign-va.tiktokcdn.com/obj/tos-mali...  ...         225400000
#
#   privateItem duetEnabled stitchEnabled shareEnabled   isAd duetDisplay  \
# 0       False        True          True         True  False           0
# 1       False       False         False         True  False           0
# 2       False       False         False         True  False           0
# 3       False        True          True         True  False           0
# 4       False        True          True         True  False           0
#
#   stitchDisplay warnInfo effectStickers
# 0             0      NaN            NaN
# 1             0      NaN            NaN
# 2             0      NaN            NaN
# 3             0      NaN            NaN
# 4             0      NaN            NaN
#
# [5 rows x 80 columns]
